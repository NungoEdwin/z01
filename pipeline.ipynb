# %%
#Exercise 1
import numpy as np

train_data = [[7, 6, 5],
              [4, np.nan, 5],
              [1, 20, 8]]
test_data = [[np.nan, 1, 2],
             [7, np.nan, 9],
             [np.nan, 2, 4]]            

train_data = [[7, 6, 5],
              [4, np.nan, 5],
              [1, 20, 8]]

imputer = SimpleImputer(strategy='mean')
imputer.fit(train_data)
print(imputer.statistics_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#       7 test_data = [[np.nan, 1, 2],
#       8              [7, np.nan, 9],
#       9              [np.nan, 2, 4]]
#      11 train_data = [[7, 6, 5],
#      12               [4, np.nan, 5],
#      13               [1, 20, 8]]
# ---> 15 imputer = SimpleImputer(strategy='mean')
#      16 imputer.fit(train_data)
#      17 print(imputer.statistics_)
#
# NameError: name 'SimpleImputer' is not defined
