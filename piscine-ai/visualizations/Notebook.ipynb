# %%
# Exercise 1: Pandas plot 1
import pandas as pd
import matplotlib.pyplot as plt

# Data
df = pd.DataFrame({
    'name': ['christopher','marion','maria','mia','clement','randy','remi'],
    'age': [70, 30, 22, 19, 45, 33, 20],
    'gender': ['M','F','F','F','M','M','M'],
    'state': ['california','dc','california','dc','california','new york','porto'],
    'num_children': [2,0,0,3,8,1,4],
    'num_pets': [5,1,0,5,2,2,3]
})

# Bar plot: age vs name
df.plot(
    x="name",
    y="age",
    kind="bar",
    title="Age of Individuals"
)

# Axis labels
plt.xlabel("Name")
plt.ylabel("Age")

plt.legend(title="Legend")

# Show plot
plt.show()

# %%
# Exercise 2: Pandas plot 2
df = pd.DataFrame({
    'name': ['christopher', 'marion', 'maria', 'mia', 'clement', 'randy', 'remi'],
    'age': [70, 30, 22, 19, 45, 33, 20],
    'gender': ['M', 'F', 'F', 'F', 'M', 'M', 'M'],
    'state': ['california', 'dc', 'california', 'dc', 'california', 'new york', 'porto'],
    'num_children': [4, 2, 1, 0, 3, 1, 0],
    'num_pets': [5, 1, 0, 2, 2, 2, 3]
})

ax = df.plot.scatter(
    x='age',
    y='num_children'
)
ax.set_title('Scatter plot: Age and Number of Children')
ax.set_xlabel('Age')
ax.set_ylabel('Number of Children')
plt.tight_layout()
plt.show()

# %%
# Exercise 3: Matplotlib 1
import matplotlib.pyplot as plt

# Example data points (integer coordinates)
x = [1, 2, 3, 4, 5, 6, 7]
y = [3, 5, 2, 6, 7, 4, 8]

# Plot with red dashdot line and blue circles
plt.plot(x, y, color="red", linestyle="dashdot", linewidth=3, marker="o", 
         markerfacecolor="blue", markersize=12)

# Title and axis labels
plt.title("Custom Matplotlib Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Limit axes
plt.xlim(1, 8)
plt.ylim(1, 8)

# Show plot
plt.show()

# %%
#Exercise 4
import matplotlib.pyplot as plt

left_data = [5, 7, 11, 13, 17]
right_data = [0.1, 0.2, 0.4, 0.8, -1.6]
x_axis = [0.0, 1.0, 2.0, 3.0, 4.0]

fig, ax1 = plt.subplots()

#Plot left data (black)
ax1.plot(x_axis, left_data, color='black', label='Left Data')
ax1.set_ylabel('Left Y-axis (name)', color='black')
ax1.tick_params(axis='y', labelcolor='black')

#Create right y-axis
ax2 = ax1.twinx()
ax2.plot(x_axis, right_data, color='red', label='Right Data')
ax2.set_ylabel('Right Y-axis (name)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Comparison of Left and Right Data on Different Y-Axes')
plt.show()

# %%
#Exercise 5: Matplotlib subplots

import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 3, figsize=(12, 6))
fig.subplots_adjust(hspace=0.5, wspace=0.5)
for i, ax in enumerate(axes.flat, start=1):
    ax.text(0.5, 0.5, f"(2,3,{i})", ha='center', va='center', fontsize=14)
    ax.set_title(f"Title {i}")
plt.show()

# %%
# Exercise 6: Plotly 1

import numpy as np
import pandas as pd
import plotly.express as px

#Generate random price data
returns = np.random.randn(50)
price = 100 + np.cumsum(returns)

dates = pd.date_range(start='2020-09-01', periods=50, freq='B')
df = pd.DataFrame(zip(dates, price),
                  columns=['Date','Company_A'])

#Plot with PLotly Express
fig = px.line(
    df,
    x='Date',
    y='Company_A',
    title='Company_1 stock price',
    labels={'Date': 'Date', 'Company_A':'Company_A'}
)
fig.show()

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot

# Initialize notebook mode
init_notebook_mode(connected=True)

# Generate reproducible data
np.random.seed(0)   # ensures we always get the same numbers
returns = np.random.randn(50)
price = 100 + np.cumsum(returns)

dates = pd.date_range(start='2020-09-01', periods=50, freq='B')
df = pd.DataFrame(zip(dates, price), columns=['Date','Company_A'])

# Create the line plot
line_price = go.Scatter(
    x=df['Date'],
    y=df['Company_A'],
    mode='lines',
    name='Company_A'
)

# Build the figure
fig = go.Figure(data=[line_price])

# Update layout to match the screenshot
fig.update_layout(
    title='Company_1 stock price',
    xaxis_title='Date',
    yaxis_title='Company_A'
)

iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>
